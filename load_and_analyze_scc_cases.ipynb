# %% [markdown]
# ### Notebook to load and analyze Supreme Court of Canada cases
#
# Sean Rehaag
#
# License: Creative Commons Attribution-NonCommercial 4.0 International [(CC BY-NC 4.0)](https://creativecommons.org/licenses/by-nc/4.0/)
#
# Dataset & Code to be cited as:
#
#     Sean Rehaag, "Supreme Court of Canada Bulk Decisions Dataset" (2023), online: Refugee Law Laboratory <RLL>.
#
# Notes:
#
# (1) Data Source: [Supreme Court of Canada](https://www.scc-csc.ca).
#
# (2) Unofficial Data: The data are unofficial reproductions of materials on the Supreme Court of Canada website. Links to official versions are included in the dataset.
#
# (3) Non-Affiliation / Endorsement: The data has been collected and reproduced without any affiliation or endorsement from the Supreme Court of Canada
#
# (4) Non-Commerical Use: As indicated in the license, data may be used for non-commercial use (with attribution) only. For commercial use, see the Supreme Court of Canada website's [Terms of Use](https://www.scc-csc.ca/terms-avis/notice-enonce-eng.aspx).
#
# (5) Accuracy: Data was collected and processed programmatically for the purposes of academic research. While we make best efforts to ensure accuracy, data gathering of this kind inevitably involves errors. As such the data should be viewed as preliminary information aimed to prompt further research and discussion, rather than as definitive information.
#
# ### Requirements:
#
#     pip install pandas
#     pip install requests
#
# (Written on Python 3.9.12)

# %%
# import libraries
import pandas as pd
import json
import pathlib

# Set variables
start_year = 1887  # First year of data sought (1887 +)
end_year = 2022  # Last year of data sought (2022 -)
language = None  # language of cases sought ('en', 'fr', or None for both)

# %% [markdown]
# ### Load Data
#
# Two Options: Local & Remote

# %%
# OPTION 1: Load data locally via repo

# Set path to data
data_path = pathlib.Path('DATA/YEARLY/')

# load data for relevant years
results = []
for year in range(start_year, end_year+1):
    with open(data_path / f'{year}.jsonl', 'r') as f:
        for line in f:
            results.append(json.loads(line))

# Create dataframe
df = pd.DataFrame(results)

# filter by language if applicable
if language:
    df = df[df['language'] == language]

df
# Out:
#                 citation citation2  year  \
# 0      (1887) 13 SCR 441            1887
# 1      (1887) 13 SCR 469            1887
# 2      (1887) 13 SCR 577            1887
# 3      (1887) 14 SCR 105            1887
# 4      (1887) 14 SCR 217            1887
# ...                  ...       ...   ...
# 15229        2022 CSC 54            2022
# 15230         2022 CSC 6            2022
# 15231         2022 CSC 7            2022
# 15232         2022 CSC 8            2022
# 15233         2022 CSC 9            2022
#
#                                               name language decision_date  \
# 0                       City of Winnipeg v. Wright       en    1887-05-11
# 1                      Ball v. Crompton Corset Co.       en    1887-03-01
# 2      St. Catharines Milling and Lumber Co. v. R.       en    1887-06-20
# 3             Canadian Pacific Ry. Co. v. Robinson       en    1887-06-20
# 4                              Fairbanks v. Barlow       en    1887-03-14
# ...                                            ...      ...           ...
# 15229                                 R. c. Beaver       fr    2022-12-09
# 15230                          Anderson c. Alberta       fr    2022-03-18
# 15231                                  R. c. White       fr    2022-03-18
# 15232                                   R. c. Pope       fr    2022-03-21
# 15233                              R. c. Samaniego       fr    2022-03-25
#
#                                               source_url scraped_timestamp  \
# 0      https://decisions.scc-csc.ca/scc-csc/scc-csc/e...        2022-08-31
# 1      https://decisions.scc-csc.ca/scc-csc/scc-csc/e...        2022-08-31
# 2      https://decisions.scc-csc.ca/scc-csc/scc-csc/e...        2022-08-31
# 3      https://decisions.scc-csc.ca/scc-csc/scc-csc/e...        2022-08-31
# 4      https://decisions.scc-csc.ca/scc-csc/scc-csc/e...        2022-08-31
# ...                                                  ...               ...
# 15229  https://decisions.scc-csc.ca/scc-csc/scc-csc/f...        2023-04-13
# 15230  https://decisions.scc-csc.ca/scc-csc/scc-csc/f...        2022-09-01
# 15231  https://decisions.scc-csc.ca/scc-csc/scc-csc/f...        2022-09-01
# 15232  https://decisions.scc-csc.ca/scc-csc/scc-csc/f...        2022-09-01
# 15233  https://decisions.scc-csc.ca/scc-csc/scc-csc/f...        2022-09-01
#
#                                          unofficial_text
# 0      City of Winnipeg v. Wright\nCollection\nSuprem...
# 1      Ball v. Crompton Corset Co.\nCollection\nSupre...
# 2      St. Catharines Milling and Lumber Co. v. R.\nC...
# 3      Canadian Pacific Ry. Co. v. Robinson\nCollecti...
# 4      Fairbanks v. Barlow\nCollection\nSupreme Court...
# ...                                                  ...
# 15229  R. c. Beaver\nCollection\nJugements de la Cour...
# 15230  Anderson c. Alberta\nCollection\nJugements de ...
# 15231  R. c. White\nCollection\nJugements de la Cour ...
# 15232  R. c. Pope\nCollection\nJugements de la Cour s...
# 15233  R. c. Samaniego\nCollection\nJugements de la C...
#
# [15234 rows x 9 columns]
